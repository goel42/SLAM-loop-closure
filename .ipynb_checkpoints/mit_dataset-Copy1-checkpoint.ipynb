# %%
dataset=r"data/input_M3500_g2o.g2o"

# %%
import graphslam
from graphslam.load import load_g2o_se2

# %%
g = load_g2o_se2(dataset)

# %%
g.plot(edge_color='w', vertex_markersize=1)

# %%
g.optimize()
# Out:
# Iteration                chi^2        rel. change
# ---------                -----        -----------
#         0         2566667.6592
#         1          419912.6919          -0.836398
#         2            4687.7932          -0.988836
#         3             229.5327          -0.951036
#         4             137.9331          -0.399070
#         5             137.9130          -0.000146
#         6             137.9130          -0.000000

# %%
g.plot()

# %%
vars(g)
# Out:
# {'_edges': [<graphslam.edge.edge_odometry.EdgeOdometry at 0x7f11e387e950>,
# ...
# ...
# ...
#   ...],
#  '_chi2': 137.91295093628196,
#  '_gradient': array([ 2.98312031e-08,  5.54988849e-08,  1.06251087e-07, ...,
#         -4.34544276e-10, -4.80269158e-11, -1.72038948e-05]),
#  '_hessian': <10500x10500 sparse matrix of type '<class 'numpy.float64'>'
#  	with 129654 stored elements in List of Lists format>}
