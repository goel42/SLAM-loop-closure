# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %%
index = pd.date_range("2021-09-01", periods=2400, freq="1H")

# %%
index
# Out:
# DatetimeIndex(['2021-09-01 00:00:00', '2021-09-01 01:00:00',
#                '2021-09-01 02:00:00', '2021-09-01 03:00:00',
#                '2021-09-01 04:00:00', '2021-09-01 05:00:00',
#                '2021-09-01 06:00:00', '2021-09-01 07:00:00',
#                '2021-09-01 08:00:00', '2021-09-01 09:00:00',
#                ...
#                '2021-12-09 14:00:00', '2021-12-09 15:00:00',
#                '2021-12-09 16:00:00', '2021-12-09 17:00:00',
#                '2021-12-09 18:00:00', '2021-12-09 19:00:00',
#                '2021-12-09 20:00:00', '2021-12-09 21:00:00',
#                '2021-12-09 22:00:00', '2021-12-09 23:00:00'],
#               dtype='datetime64[ns]', length=2400, freq='H')

# %%
df = pd.DataFrame({"a": np.arange(2400), "b": list("abcaddbe" * 300)}, index=index)
ddf = dd.from_pandas(df, npartitions=10)

# %%
data = np.arange(100_000).reshape(200, 500)
a = da.from_array(data, chunks=(100, 100))
b = da.from_array(data, chunks=(13, 13))

# %%
a.visualize(), b.chunks
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/mule/.venv/lib/python3.7/site-packages/graphviz/backend/execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      82             assert iter(input_lines) is input_lines
# ---> 83             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      84         else:
#
# ~/mule/.venv/lib/python3.7/site-packages/graphviz/backend/execute.py in _run_input_lines(cmd, input_lines, kwargs)
#     102 def _run_input_lines(cmd, input_lines, *, kwargs):
# --> 103     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     104
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: PosixPath('dot'): PosixPath('dot')
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-9-dbccc2950f52> in <module>
# ----> 1 a.visualize(), b.chunks
#
# ~/mule/.venv/lib/python3.7/site-packages/dask/base.py in visualize(self, filename, format, optimize_graph, **kwargs)
#     217             format=format,
#     218             optimize_graph=optimize_graph,
# --> 219             **kwargs,
#     220         )
#     221
#
# ~/mule/.venv/lib/python3.7/site-packages/dask/base.py in visualize(filename, optimize_graph, maxval, *args, **kwargs)
#     741         raise NotImplementedError("Unknown value color=%s" % color)
#     742
# --> 743     return dot_graph(dsk, filename=filename, **kwargs)
#     744
#     745
#
# ~/mule/.venv/lib/python3.7/site-packages/dask/dot.py in dot_graph(dsk, filename, format, **kwargs)
#     269     """
#     270     g = to_graphviz(dsk, **kwargs)
# --> 271     return graphviz_to_file(g, filename, format)
#     272
#     273
#
# ~/mule/.venv/lib/python3.7/site-packages/dask/dot.py in graphviz_to_file(g, filename, format)
#     286         format = "png"
#     287
# --> 288     data = g.pipe(format=format)
#     289     if not data:
#     290         raise RuntimeError(
#
# ~/mule/.venv/lib/python3.7/site-packages/graphviz/piping.py in pipe(self, format, renderer, formatter, quiet, engine, encoding)
#     114             raw = self._pipe_lines(*args, input_encoding=self._encoding, **kwargs)
#     115             return raw.decode(encoding)
# --> 116         return self._pipe_lines(*args, input_encoding=self._encoding, **kwargs)
#
# ~/mule/.venv/lib/python3.7/site-packages/graphviz/backend/piping.py in pipe_lines(engine, format, input_lines, input_encoding, renderer, formatter, quiet)
#     147     kwargs = {'input_lines': (line.encode(input_encoding) for line in input_lines)}
#     148
# --> 149     proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     150     return proc.stdout
#     151
#
# ~/mule/.venv/lib/python3.7/site-packages/graphviz/backend/execute.py in run_check(cmd, input_lines, encoding, capture_output, quiet, **kwargs)
#      86     except OSError as e:
#      87         if e.errno == errno.ENOENT:
# ---> 88             raise ExecutableNotFound(cmd) from e
#      89         raise
#      90
#
# ExecutableNotFound: failed to execute PosixPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
# !pip install graphviz
# !apt-get install graphviz
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/anujraaj/mule/.venv/lib/python3.7/site-packages (from pydot) (2.4.6)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/anujraaj/mule/.venv/bin/python -m pip install --upgrade pip' command.

# %%
b.blocks[]

# %%
a.blocks[1,4]

# %%
a.chunks

# %%
a.blocks

# %%
a[0,0].compute()
